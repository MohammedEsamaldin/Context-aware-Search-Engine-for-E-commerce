# %%
import pandas as pd
import json
from datetime import datetime
# Out:
# C:\Users\Viriya Duch Sam\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df_products = pd.read_parquet('raw/shopping_queries_dataset_products.parquet')
df_products.head()
# Out:
#    product_id                                      product_title  \
# 0  B079VKKJN7  11 Degrees de los Hombres Playera con Logo, Ne...
# 1  B079Y9VRKS          Camiseta Eleven Degrees Core TS White (M)
# 2  B07DP4LM9H  11 Degrees de los Hombres Core Pull Over Hoodi...
# 3  B07G37B9HP          11 Degrees Poli Panel Track Pant XL Black
# 4  B07LCTGDHY  11 Degrees Gorra Trucker Negro OSFA (Talla úni...
#
#                                  product_description  \
# 0  Esta playera con el logo de la marca Carrier d...
# 1                                               None
# 2  La sudadera con capucha Core Pull Over de 11 G...
# 3                                               None
# 4                                               None
#
#                                 product_bullet_point product_brand  \
# 0  11 Degrees Negro Playera con logo\nA estrenar ...    11 Degrees
# 1                                               None    11 Degrees
# 2  11 Degrees Azul Core Pull Over Hoodie\nA estre...    11 Degrees
# 3                                               None    11 Degrees
# 4                                               None    11 Degrees
#
#   product_color product_locale
# 0         Negro             es
# 1        Blanco             es
# 2          Azul             es
# 3          None             es
# 4       Negro (             es

# %%
## Filter only 1000 subset to prevent overly large file size
# Product_description != None, product_locale = 'us'
df_filtered = df_products[
    (df_products['product_description'].notnull())  
    & (df_products['product_locale'] == 'us')
].sample(n=1000, random_state=42)

df_filtered = df_filtered.rename(columns={
    'product_id': 'id',
    'product_title': 'title',
    'product_description': 'description',
    'product_bullet_point': 'bullet_point',
    'product_brand': 'brand',
    'product_color': 'color',
    'product_locale': 'locale'
})
df_filtered['embedding'] = [[]] * len(df_filtered)
df_filtered.where(pd.notnull(df_filtered), None)
df_filtered.head(3)
# Out:
#                  id                                              title  \
# 1393112  B098SF7Y8K  KORANGE Ginger Jars Blue and White Ceramic Jar...
# 850629   B08RN1NGHQ  V-TIMMIX Armless Accent Chair Cover Slipcover,...
# 823090   B08MB2ZKT2  Atwood | Dometic WH-6GA Water Heater #94001BP ...
#
#                                                description  \
# 1393112             🍀【Package Includes】1 x Ginger Jar Vase
# 850629   <p>Dear Customer:</p><p></p><p>Thank you for c...
# 823090   DOMETIC WH-6GA 6 GALLON WATER HEATER (GAS ONLY...
#
#                                               bullet_point             brand  \
# 1393112  🍀【CLASSIC HOME DECOR】The Chinese Ceramic Jar i...           KORANGE
# 850629   ◆[Suitable for style]：TRANSFORM THE LOOK OF YO...          V-TIMMIX
# 823090   10,000 BTU input\n6 gal. cut-out: 12-3/4"H x 1...  Atwood | Dometic
#
#              color locale embedding
# 1393112       None     us        []
# 850629   Navy Blue     us        []
# 823090        None     us        []

# %%
## Save filtered df 
output_path = 'processed/products.json'
df_filtered.to_json(output_path, orient='records', indent=2)

# %%
## Mock User Data
# Define a variable for the current timestamp in ISO format
current_timestamp = datetime.now().isoformat()

# Define the list of user profiles, using current_timestamp for lastLogin
user_profiles = [
    {
        "userId": "user001",
        "name": "Alice Brown",
        "email": "alice.brown@example.com",
        "preferences": {
            "favoriteBrands": ["korange", "shein", "aden + anais"],
            "interests": ["home decor", "handmade design", "newborn care", "infant fashion"]
        },
        "lastLogin": current_timestamp
    },
    {
        "userId": "user002",
        "name": "Bob Smith",
        "email": "bob.smith@example.com",
        "preferences": {
            "favoriteBrands": ["v-timmix", "nigo valve", "kastking"],
            "interests": ["furniture protection", "rv lifestyle", "fishing"]
        },
        "lastLogin": current_timestamp
    },
    {
        "userId": "user003",
        "name": "Charlie Johnson",
        "email": "charlie.johnson@example.com",
        "preferences": {
            "favoriteBrands": ["ushield", "woodraphic", "polar seltzer"],
            "interests": ["mobile accessories", "woodworking", "diy crafts"]
        },
        "lastLogin": current_timestamp
    }
]

# Write the data to a JSON file
with open('processed/users.json', 'w') as file:
    json.dump(user_profiles, file, indent=2)

# %%
## Mock session data
user_sessions = [
    {
    "sessionId": "session_20250407_user001_1",
    "userId": "user001",
    "startTime": "2025-04-07T09:30:00Z",
    "endTime": "2025-04-07T10:15:00Z",
    "queries": [
        {
        "queryId": "q1",
        "text": "organic baby clothes",
        "timestamp": "2025-04-07T09:30:00Z"
        },
        {
        "queryId": "q2",
        "text": "aden + anais swaddles",
        "timestamp": "2025-04-07T09:42:00Z"
        },
        {
        "queryId": "q3",
        "text": "handmade nursery decor",
        "timestamp": "2025-04-07T10:05:00Z"
        }
    ],
    "transitions": [
        {
        "from": "q1",
        "to": "q2",
        "count": 1,
        "timeDifference": 12,
        "weight": 0.61
        },
        {
        "from": "q2",
        "to": "q3",
        "count": 1,
        "timeDifference": 23,
        "weight": 0.42
        }
    ]
    },
    {
    "sessionId": "session_20250407_user002_1",
    "userId": "user002",
    "startTime": "2025-04-07T14:00:00Z",
    "endTime": "2025-04-07T14:45:00Z",
    "queries": [
        {
        "queryId": "q1",
        "text": "rv furniture covers",
        "timestamp": "2025-04-07T14:00:00Z"
        },
        {
        "queryId": "q2",
        "text": "kastking fishing reels",
        "timestamp": "2025-04-07T14:15:00Z"
        },
        {
        "queryId": "q3",
        "text": "waterproof couch protectors",
        "timestamp": "2025-04-07T14:35:00Z"
        }
    ],
    "transitions": [
        {
        "from": "q1",
        "to": "q2",
        "count": 1,
        "timeDifference": 15,
        "weight": 0.55
        },
        {
        "from": "q2",
        "to": "q3",
        "count": 1,
        "timeDifference": 20,
        "weight": 0.45
        }
    ]
    },
    {
    "sessionId": "session_20250407_user003_1",
    "userId": "user003",
    "startTime": "2025-04-07T16:20:00Z",
    "endTime": "2025-04-07T17:00:00Z",
    "queries": [
        {
        "queryId": "q1",
        "text": "phone wood cases",
        "timestamp": "2025-04-07T16:20:00Z"
        },
        {
        "queryId": "q2",
        "text": "polar seltzer cooler",
        "timestamp": "2025-04-07T16:35:00Z"
        },
        {
        "queryId": "q3",
        "text": "diy wood desk plans",
        "timestamp": "2025-04-07T16:50:00Z"
        }
    ],
    "transitions": [
        {
        "from": "q1",
        "to": "q2",
        "count": 1,
        "timeDifference": 15,
        "weight": 0.55
        },
        {
        "from": "q2",
        "to": "q3",
        "count": 1,
        "timeDifference": 15,
        "weight": 0.55
        }
    ]
    }
]
# Write the data to a JSON file
with open('processed/sessions.json', 'w') as file:
    json.dump(user_sessions, file, indent=2)

# %%
## Mock Query Log data
query_logs = [
  {
    "logId": "log_20250407_user001_q1",
    "userId": "user001",
    "sessionId": "session_20250407_user001_1",
    "rawQuery": "organic baby clothes",
    "refinedQuery": "organic baby clothes baby swaddles nursery decor",
    "timestamp": "2025-04-07T09:30:00Z",
    "retrievalResults": {
      "BM25": ["B0883DXZYV", "B082KL8GP1"],
      "Vector": ["B0883DXZYV", "B098SF7Y8K"]
    },
    "finalResults": ["B0883DXZYV", "B098SF7Y8K", "B082KL8GP1"]
  },
  {
    "logId": "log_20250407_user001_q2",
    "userId": "user001",
    "sessionId": "session_20250407_user001_1",
    "rawQuery": "aden + anais swaddles",
    "refinedQuery": "aden + anais swaddles",
    "timestamp": "2025-04-07T09:42:00Z",
    "retrievalResults": {
      "BM25": ["B0883DXZYV"],
      "Vector": ["B0883DXZYV"]
    },
    "finalResults": ["B0883DXZYV"]
  },
  {
    "logId": "log_20250407_user001_q3",
    "userId": "user001",
    "sessionId": "session_20250407_user001_1",
    "rawQuery": "handmade nursery decor",
    "refinedQuery": "handmade nursery decor elegant home decor",
    "timestamp": "2025-04-07T10:05:00Z",
    "retrievalResults": {
      "BM25": ["B098SF7Y8K", "B082KL8GP1"],
      "Vector": ["B098SF7Y8K"]
    },
    "finalResults": ["B098SF7Y8K", "B082KL8GP1"]
  },
  {
    "logId": "log_20250407_user002_q1",
    "userId": "user002",
    "sessionId": "session_20250407_user002_1",
    "rawQuery": "rv furniture covers",
    "refinedQuery": "rv furniture covers durable upholstery covers",
    "timestamp": "2025-04-07T14:00:00Z",
    "retrievalResults": {
      "BM25": ["B08RN1NGHQ"],
      "Vector": ["B08RN1NGHQ"]
    },
    "finalResults": ["B08RN1NGHQ"]
  },
  {
    "logId": "log_20250407_user002_q2",
    "userId": "user002",
    "sessionId": "session_20250407_user002_1",
    "rawQuery": "kastking fishing reels",
    "refinedQuery": "kastking fishing reels high performance",
    "timestamp": "2025-04-07T14:15:00Z",
    "retrievalResults": {
      "BM25": ["B07VWHDJ3T"],
      "Vector": ["B07VWHDJ3T"]
    },
    "finalResults": ["B07VWHDJ3T"]
  },
  {
    "logId": "log_20250407_user002_q3",
    "userId": "user002",
    "sessionId": "session_20250407_user002_1",
    "rawQuery": "waterproof couch protectors",
    "refinedQuery": "waterproof couch protectors for rv",
    "timestamp": "2025-04-07T14:35:00Z",
    "retrievalResults": {
      "BM25": ["B08RN1NGHQ"],
      "Vector": ["B08RN1NGHQ"]
    },
    "finalResults": ["B08RN1NGHQ"]
  },
  {
    "logId": "log_20250407_user003_q1",
    "userId": "user003",
    "sessionId": "session_20250407_user003_1",
    "rawQuery": "phone wood cases",
    "refinedQuery": "wooden phone cases custom",
    "timestamp": "2025-04-07T16:20:00Z",
    "retrievalResults": {
      "BM25": ["B07RD414P4"],
      "Vector": ["B07RD414P4"]
    },
    "finalResults": ["B07RD414P4"]
  },
  {
    "logId": "log_20250407_user003_q2",
    "userId": "user003",
    "sessionId": "session_20250407_user003_1",
    "rawQuery": "polar seltzer cooler",
    "refinedQuery": "polar seltzer cooler insulated",
    "timestamp": "2025-04-07T16:35:00Z",
    "retrievalResults": {
      "BM25": ["B07CZK59W2"],
      "Vector": ["B07CZK59W2"]
    },
    "finalResults": ["B07CZK59W2"]
  },
  {
    "logId": "log_20250407_user003_q3",
    "userId": "user003",
    "sessionId": "session_20250407_user003_1",
    "rawQuery": "diy wood desk plans",
    "refinedQuery": "diy wood desk plans woodworking",
    "timestamp": "2025-04-07T16:50:00Z",
    "retrievalResults": {
      "BM25": ["B07DNKG8NR"],
      "Vector": ["B07DNKG8NR"]
    },
    "finalResults": ["B07DNKG8NR"]
  }
]

# Write the data to a JSON file
with open('processed/query_logs.json', 'w') as file:
    json.dump(query_logs, file, indent=2)
